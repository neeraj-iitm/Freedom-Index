# %%
import numpy as np
import pandas as pd
from tabula import read_pdf
import pickle
import fitz

# %%
mainIndicatorList = ['Human Freedom','Economic Freedom','Rule of Law', 'Security and Safety', 'Movement','Religious Freedom','Assoc., Assembly, and Civil Soc.','Expression and Information','Identity and Relationships','','']
lists = ['Country/Territory' , 'Personal Freedom', 'PF Rank', 'Economic Freedom', 'EF Rank', 'Human Freedom','HF Rank']

# %%
def get_data(page_no):
    try :
        assert page_no >= 0
        assert page_no <=420
        
        print("Getting data for page no. : ", page_no , "\n")
        
        df = read_pdf('hfi2020.pdf',pages=str(page_no))
        df = df[0]
        df.rename( columns={'Unnamed: 0':'Indicator'}, inplace=True )
        df = df.dropna()
        
        def strip(text):
            try:
                return text.replace(" ", "")

            except AttributeError:
                return text
            
        for ind, column in enumerate(df.columns):
            if ind>0:
                df[column]=df[column].apply(lambda x : strip(x))
                
        df = df.reset_index()
        df = df.drop('index',axis=1)
        print("Data for pageno ", page_no, " successfully imported.\n","--"*40,"\n")
        return df
    
    except AssertionError:
        print(f"{page_no} looks Like an Invalid Page number")

# %%
def clean_transpose(dictionary):

    country_names    = list(dictionary.keys())
    updated_datadict = {}
    for i in country_names:

        indicator_name = list(dictionary[i].transpose().iloc[0])
        transposed_df  = dictionary[i].replace('-', np.nan).transpose().iloc[1:]
        transposed_df.columns = indicator_name
        transposed_df  = transposed_df.transform(lambda x: pd.to_numeric(x))
        transposed_df  = transposed_df.transform(lambda x : x.fillna(x.mean()))
        updated_datadict[i]=transposed_df
        
    return updated_datadict

# %%
def store_data(datadict, filename = 'HFI_Countries.pickle'):
    import pickle

    # Store data (serialize)
    with open(filename, 'wb') as handle:
        pickle.dump(datadict, handle, protocol=pickle.HIGHEST_PROTOCOL)

    # Load data (deserialize)
    with open(filename, 'rb') as handle:
        unserialized_data = pickle.load(handle)

    return print("--"*18 + "Done" + "--"*18)

# %%
datadict={}

doc = fitz.open('hfi2020.pdf')
for i in range(57,364,2):
    page = doc.loadPage(i-1)
    text = page.getText('blocks')
    countryname=text[-1][-3].split("\n")[0]
    print(countryname)
    df   = get_data(i)
    datadict[countryname] = df

for i in range(364,380,2):
    page = doc.loadPage(i)
    text = page.getText('blocks')
    countryname = text[-1][-3].split("\n")[2]
    print(countryname)
    df = get_data(i)
    datadict[countryname] = df
    
doc.close()
# Out:
# Getting data for page no. :  57
#
# Data for pageno  57  successfully imported.
#  --------------------------------------------------------------------------------
#
# ALBANIA
# Getting data for page no. :  59
#
# Data for pageno  59  successfully imported.
#  --------------------------------------------------------------------------------
#
# ALGERIA
# Getting data for page no. :  61
#
# Data for pageno  61  successfully imported.
#  --------------------------------------------------------------------------------
#
# ANGOLA
# Getting data for page no. :  63
#
# Data for pageno  63  successfully imported.
#  --------------------------------------------------------------------------------
#
# ARGENTINA
# Getting data for page no. :  65
#
# Data for pageno  65  successfully imported.
#  --------------------------------------------------------------------------------
#
# ARMENIA
# Getting data for page no. :  67
#
# Data for pageno  67  successfully imported.
#  --------------------------------------------------------------------------------
#
# AUSTRALIA
# Getting data for page no. :  69
#
# Data for pageno  69  successfully imported.
#  --------------------------------------------------------------------------------
#
# AUSTRIA
# Getting data for page no. :  71
#
# Data for pageno  71  successfully imported.
#  --------------------------------------------------------------------------------
#
# AZERBAIJAN
# Getting data for page no. :  73
#
# Data for pageno  73  successfully imported.
#  --------------------------------------------------------------------------------
#
# BAHAMAS, THE
# Getting data for page no. :  75
#
# Data for pageno  75  successfully imported.
#  --------------------------------------------------------------------------------
#
# BAHRAIN
# Getting data for page no. :  77
#
# Data for pageno  77  successfully imported.
#  --------------------------------------------------------------------------------
#
# BANGLADESH
# Getting data for page no. :  79
#
# Data for pageno  79  successfully imported.
#  --------------------------------------------------------------------------------
#
# BARBADOS
# Getting data for page no. :  81
#
# Data for pageno  81  successfully imported.
#  --------------------------------------------------------------------------------
#
# BELARUS
# Getting data for page no. :  83
#
# Data for pageno  83  successfully imported.
#  --------------------------------------------------------------------------------
#
# BELGIUM
# Getting data for page no. :  85
#
# Data for pageno  85  successfully imported.
#  --------------------------------------------------------------------------------
#
# BELIZE
# Getting data for page no. :  87
#
# Data for pageno  87  successfully imported.
#  --------------------------------------------------------------------------------
#
# BENIN
# Getting data for page no. :  89
#
# Data for pageno  89  successfully imported.
#  --------------------------------------------------------------------------------
#
# BHUTAN
# Getting data for page no. :  91
#
# Data for pageno  91  successfully imported.
#  --------------------------------------------------------------------------------
#
# BOLIVIA
# Getting data for page no. :  93
#
# Data for pageno  93  successfully imported.
#  --------------------------------------------------------------------------------
#
# BOSNIA AND HERZEGOVINA
# Getting data for page no. :  95
#
# Data for pageno  95  successfully imported.
#  --------------------------------------------------------------------------------
#
# BOTSWANA
# Getting data for page no. :  97
#
# Data for pageno  97  successfully imported.
#  --------------------------------------------------------------------------------
#
# BRAZIL
# Getting data for page no. :  99
#
# Data for pageno  99  successfully imported.
#  --------------------------------------------------------------------------------
#
# BRUNEI DARUSSALAM
# Getting data for page no. :  101
#
# Data for pageno  101  successfully imported.
#  --------------------------------------------------------------------------------
#
# BULGARIA
# Getting data for page no. :  103
#
# Data for pageno  103  successfully imported.
#  --------------------------------------------------------------------------------
#
# BURKINA FASO
# Getting data for page no. :  105
#
# Data for pageno  105  successfully imported.
#  --------------------------------------------------------------------------------
#
# BURUNDI
# Getting data for page no. :  107
#
# Data for pageno  107  successfully imported.
#  --------------------------------------------------------------------------------
#
# CABO VERDE
# Getting data for page no. :  109
#
# Data for pageno  109  successfully imported.
#  --------------------------------------------------------------------------------
#
# CAMBODIA
# Getting data for page no. :  111
#
# Data for pageno  111  successfully imported.
#  --------------------------------------------------------------------------------
#
# CAMEROON
# Getting data for page no. :  113
#
# Data for pageno  113  successfully imported.
#  --------------------------------------------------------------------------------
#
# CANADA
# Getting data for page no. :  115
#
# Data for pageno  115  successfully imported.
#  --------------------------------------------------------------------------------
#
# CENTRAL AFRICAN REPUBLIC
# Getting data for page no. :  117
#
# Data for pageno  117  successfully imported.
#  --------------------------------------------------------------------------------
#
# CHAD
# Getting data for page no. :  119
#
# Data for pageno  119  successfully imported.
#  --------------------------------------------------------------------------------
#
# CHILE
# Getting data for page no. :  121
#
# Data for pageno  121  successfully imported.
#  --------------------------------------------------------------------------------
#
# CHINA
# Getting data for page no. :  123
#
# Data for pageno  123  successfully imported.
#  --------------------------------------------------------------------------------
#
# COLOMBIA
# Getting data for page no. :  125
#
# Data for pageno  125  successfully imported.
#  --------------------------------------------------------------------------------
#
# CONGO, DEM. REP.
# Getting data for page no. :  127
#
# Data for pageno  127  successfully imported.
#  --------------------------------------------------------------------------------
#
# CONGO, REP. OF
# Getting data for page no. :  129
#
# Data for pageno  129  successfully imported.
#  --------------------------------------------------------------------------------
#
# COSTA RICA
# Getting data for page no. :  131
#
# Data for pageno  131  successfully imported.
#  --------------------------------------------------------------------------------
#
# CÔTE D’IVOIRE
# Getting data for page no. :  133
#
# Data for pageno  133  successfully imported.
#  --------------------------------------------------------------------------------
#
# CROATIA
# Getting data for page no. :  135
#
# Data for pageno  135  successfully imported.
#  --------------------------------------------------------------------------------
#
# CYPRUS
# Getting data for page no. :  137
#
# Data for pageno  137  successfully imported.
#  --------------------------------------------------------------------------------
#
# CZECH REPUBLIC
# Getting data for page no. :  139
#
# Data for pageno  139  successfully imported.
#  --------------------------------------------------------------------------------
#
# DENMARK
# Getting data for page no. :  141
#
# Data for pageno  141  successfully imported.
#  --------------------------------------------------------------------------------
#
# DOMINICAN REPUBLIC
# Getting data for page no. :  143
#
# Data for pageno  143  successfully imported.
#  --------------------------------------------------------------------------------
#
# ECUADOR
# Getting data for page no. :  145
#
# Data for pageno  145  successfully imported.
#  --------------------------------------------------------------------------------
#
# EGYPT, ARAB REP.
# Getting data for page no. :  147
#
# Data for pageno  147  successfully imported.
#  --------------------------------------------------------------------------------
#
# EL SALVADOR
# Getting data for page no. :  149
#
# Data for pageno  149  successfully imported.
#  --------------------------------------------------------------------------------
#
# ESTONIA
# Getting data for page no. :  151
#
# Data for pageno  151  successfully imported.
#  --------------------------------------------------------------------------------
#
# ESWATINI
# Getting data for page no. :  153
# Data for pageno  153  successfully imported.
#  --------------------------------------------------------------------------------
#
# ETHIOPIA
# Getting data for page no. :  155
#
# Data for pageno  155  successfully imported.
#  --------------------------------------------------------------------------------
#
# FIJI
# Getting data for page no. :  157
#
# Data for pageno  157  successfully imported.
#  --------------------------------------------------------------------------------
#
# FINLAND
# Getting data for page no. :  159
#
# Data for pageno  159  successfully imported.
#  --------------------------------------------------------------------------------
#
# FRANCE
# Getting data for page no. :  161
#
# Data for pageno  161  successfully imported.
#  --------------------------------------------------------------------------------
#
# GABON
# Getting data for page no. :  163
#
# Data for pageno  163  successfully imported.
#  --------------------------------------------------------------------------------
#
# GAMBIA, THE
# Getting data for page no. :  165
#
# Data for pageno  165  successfully imported.
#  --------------------------------------------------------------------------------
#
# GEORGIA
# Getting data for page no. :  167
#
# Data for pageno  167  successfully imported.
#  --------------------------------------------------------------------------------
#
# GERMANY
# Getting data for page no. :  169
#
# Data for pageno  169  successfully imported.
#  --------------------------------------------------------------------------------
#
# GHANA
# Getting data for page no. :  171
#
# Data for pageno  171  successfully imported.
#  --------------------------------------------------------------------------------
#
# GREECE
# Getting data for page no. :  173
#
# Data for pageno  173  successfully imported.
#  --------------------------------------------------------------------------------
#
# GUATEMALA
# Getting data for page no. :  175
#
# Data for pageno  175  successfully imported.
#  --------------------------------------------------------------------------------
#
# GUINEA
# Getting data for page no. :  177
#
# Data for pageno  177  successfully imported.
#  --------------------------------------------------------------------------------
#
# GUINEA-BISSAU
# Getting data for page no. :  179
#
# Data for pageno  179  successfully imported.
#  --------------------------------------------------------------------------------
#
# GUYANA
# Getting data for page no. :  181
#
# Data for pageno  181  successfully imported.
#  --------------------------------------------------------------------------------
#
# HAITI
# Getting data for page no. :  183
#
# Data for pageno  183  successfully imported.
#  --------------------------------------------------------------------------------
#
# HONDURAS
# Getting data for page no. :  185
#
# Data for pageno  185  successfully imported.
#  --------------------------------------------------------------------------------
#
# HONG KONG SAR, CHINA
# Getting data for page no. :  187
#
# Data for pageno  187  successfully imported.
#  --------------------------------------------------------------------------------
#
# HUNGARY
# Getting data for page no. :  189
#
# Data for pageno  189  successfully imported.
#  --------------------------------------------------------------------------------
#
# ICELAND
# Getting data for page no. :  191
#
# Data for pageno  191  successfully imported.
#  --------------------------------------------------------------------------------
#
# INDIA
# Getting data for page no. :  193
#
# Data for pageno  193  successfully imported.
#  --------------------------------------------------------------------------------
#
# INDONESIA
# Getting data for page no. :  195
#
# Data for pageno  195  successfully imported.
#  --------------------------------------------------------------------------------
#
# IRAN, ISLAMIC REP.
# Getting data for page no. :  197
#
# Data for pageno  197  successfully imported.
#  --------------------------------------------------------------------------------
#
# IRAQ
# Getting data for page no. :  199
#
# Data for pageno  199  successfully imported.
#  --------------------------------------------------------------------------------
#
# IRELAND
# Getting data for page no. :  201
#
# Data for pageno  201  successfully imported.
#  --------------------------------------------------------------------------------
#
# ISRAEL
# Getting data for page no. :  203
#
# Data for pageno  203  successfully imported.
#  --------------------------------------------------------------------------------
#
# ITALY
# Getting data for page no. :  205
#
# Data for pageno  205  successfully imported.
#  --------------------------------------------------------------------------------
#
# JAMAICA
# Getting data for page no. :  207
#
# Data for pageno  207  successfully imported.
#  --------------------------------------------------------------------------------
#
# JAPAN
# Getting data for page no. :  209
#
# Data for pageno  209  successfully imported.
#  --------------------------------------------------------------------------------
#
# JORDAN
# Getting data for page no. :  211
#
# Data for pageno  211  successfully imported.
#  --------------------------------------------------------------------------------
#
# KAZAKHSTAN
# Getting data for page no. :  213
#
# Data for pageno  213  successfully imported.
#  --------------------------------------------------------------------------------
#
# KENYA
# Getting data for page no. :  215
#
# Data for pageno  215  successfully imported.
#  --------------------------------------------------------------------------------
#
# KOREA, REP. OF
# Getting data for page no. :  217
#
# Data for pageno  217  successfully imported.
#  --------------------------------------------------------------------------------
#
# KUWAIT
# Getting data for page no. :  219
#
# Data for pageno  219  successfully imported.
#  --------------------------------------------------------------------------------
#
# KYRGYZ REPUBLIC
# Getting data for page no. :  221
#
# Data for pageno  221  successfully imported.
#  --------------------------------------------------------------------------------
#
# LAO PDR
# Getting data for page no. :  223
#
# Data for pageno  223  successfully imported.
#  --------------------------------------------------------------------------------
#
# LATVIA
# Getting data for page no. :  225
#
# Data for pageno  225  successfully imported.
#  --------------------------------------------------------------------------------
#
# LEBANON
# Getting data for page no. :  227
#
# Data for pageno  227  successfully imported.
#  --------------------------------------------------------------------------------
#
# LESOTHO
# Getting data for page no. :  229
#
# Data for pageno  229  successfully imported.
#  --------------------------------------------------------------------------------
#
# LIBERIA
# Getting data for page no. :  231
#
# Data for pageno  231  successfully imported.
#  --------------------------------------------------------------------------------
#
# LIBYA
# Getting data for page no. :  233
#
# Data for pageno  233  successfully imported.
#  --------------------------------------------------------------------------------
#
# LITHUANIA
# Getting data for page no. :  235
#
# Data for pageno  235  successfully imported.
#  --------------------------------------------------------------------------------
#
# LUXEMBOURG
# Getting data for page no. :  237
#
# Data for pageno  237  successfully imported.
#  --------------------------------------------------------------------------------
#
# MADAGASCAR
# Getting data for page no. :  239
#
# Data for pageno  239  successfully imported.
#  --------------------------------------------------------------------------------
#
# MALAWI
# Getting data for page no. :  241
#
# Data for pageno  241  successfully imported.
#  --------------------------------------------------------------------------------
#
# MALAYSIA
# Getting data for page no. :  243
#
# Data for pageno  243  successfully imported.
#  --------------------------------------------------------------------------------
#
# MALI
# Getting data for page no. :  245
#
# Data for pageno  245  successfully imported.
#  --------------------------------------------------------------------------------
#
# MALTA
# Getting data for page no. :  247
#
# Data for pageno  247  successfully imported.
#  --------------------------------------------------------------------------------
#
# MAURITANIA
# Getting data for page no. :  249
# Data for pageno  249  successfully imported.
#  --------------------------------------------------------------------------------
#
# MAURITIUS
# Getting data for page no. :  251
#
# Data for pageno  251  successfully imported.
#  --------------------------------------------------------------------------------
#
# MEXICO
# Getting data for page no. :  253
#
# Data for pageno  253  successfully imported.
#  --------------------------------------------------------------------------------
#
# MOLDOVA
# Getting data for page no. :  255
#
# Data for pageno  255  successfully imported.
#  --------------------------------------------------------------------------------
#
# MONGOLIA
# Getting data for page no. :  257
#
# Data for pageno  257  successfully imported.
#  --------------------------------------------------------------------------------
#
# MONTENEGRO
# Getting data for page no. :  259
#
# Data for pageno  259  successfully imported.
#  --------------------------------------------------------------------------------
#
# MOROCCO
# Getting data for page no. :  261
#
# Data for pageno  261  successfully imported.
#  --------------------------------------------------------------------------------
#
# MOZAMBIQUE
# Getting data for page no. :  263
#
# Data for pageno  263  successfully imported.
#  --------------------------------------------------------------------------------
#
# MYANMAR
# Getting data for page no. :  265
#
# Data for pageno  265  successfully imported.
#  --------------------------------------------------------------------------------
#
# NAMIBIA
# Getting data for page no. :  267
#
# Data for pageno  267  successfully imported.
#  --------------------------------------------------------------------------------
#
# NEPAL
# Getting data for page no. :  269
#
# Data for pageno  269  successfully imported.
#  --------------------------------------------------------------------------------
#
# NETHERLANDS
# Getting data for page no. :  271
#
# Data for pageno  271  successfully imported.
#  --------------------------------------------------------------------------------
#
# NEW ZEALAND
# Getting data for page no. :  273
#
# Data for pageno  273  successfully imported.
#  --------------------------------------------------------------------------------
#
# NICARAGUA
# Getting data for page no. :  275
#
# Data for pageno  275  successfully imported.
#  --------------------------------------------------------------------------------
#
# NIGER
# Getting data for page no. :  277
#
# Data for pageno  277  successfully imported.
#  --------------------------------------------------------------------------------
#
# NIGERIA
# Getting data for page no. :  279
#
# Data for pageno  279  successfully imported.
#  --------------------------------------------------------------------------------
#
# NORTH MACEDONIA
# Getting data for page no. :  281
#
# Data for pageno  281  successfully imported.
#  --------------------------------------------------------------------------------
#
# NORWAY
# Getting data for page no. :  283
#
# Data for pageno  283  successfully imported.
#  --------------------------------------------------------------------------------
#
# OMAN
# Getting data for page no. :  285
#
# Data for pageno  285  successfully imported.
#  --------------------------------------------------------------------------------
#
# PAKISTAN
# Getting data for page no. :  287
#
# Data for pageno  287  successfully imported.
#  --------------------------------------------------------------------------------
#
# PANAMA
# Getting data for page no. :  289
#
# Data for pageno  289  successfully imported.
#  --------------------------------------------------------------------------------
#
# PAPUA NEW GUINEA
# Getting data for page no. :  291
#
# Data for pageno  291  successfully imported.
#  --------------------------------------------------------------------------------
#
# PARAGUAY
# Getting data for page no. :  293
#
# Data for pageno  293  successfully imported.
#  --------------------------------------------------------------------------------
#
# PERU
# Getting data for page no. :  295
#
# Data for pageno  295  successfully imported.
#  --------------------------------------------------------------------------------
#
# PHILIPPINES
# Getting data for page no. :  297
#
# Data for pageno  297  successfully imported.
#  --------------------------------------------------------------------------------
#
# POLAND
# Getting data for page no. :  299
#
# Data for pageno  299  successfully imported.
#  --------------------------------------------------------------------------------
#
# PORTUGAL
# Getting data for page no. :  301
#
# Data for pageno  301  successfully imported.
#  --------------------------------------------------------------------------------
#
# QATAR
# Getting data for page no. :  303
#
# Data for pageno  303  successfully imported.
#  --------------------------------------------------------------------------------
#
# ROMANIA
# Getting data for page no. :  305
#
# Data for pageno  305  successfully imported.
#  --------------------------------------------------------------------------------
#
# RUSSIAN FEDERATION
# Getting data for page no. :  307
#
# Data for pageno  307  successfully imported.
#  --------------------------------------------------------------------------------
#
# RWANDA
# Getting data for page no. :  309
#
# Data for pageno  309  successfully imported.
#  --------------------------------------------------------------------------------
#
# SAUDI ARABIA
# Getting data for page no. :  311
#
# Data for pageno  311  successfully imported.
#  --------------------------------------------------------------------------------
#
# SENEGAL
# Getting data for page no. :  313
#
# Data for pageno  313  successfully imported.
#  --------------------------------------------------------------------------------
#
# SERBIA
# Getting data for page no. :  315
#
# Data for pageno  315  successfully imported.
#  --------------------------------------------------------------------------------
#
# SEYCHELLES
# Getting data for page no. :  317
#
# Data for pageno  317  successfully imported.
#  --------------------------------------------------------------------------------
#
# SIERRA LEONE
# Getting data for page no. :  319
#
# Data for pageno  319  successfully imported.
#  --------------------------------------------------------------------------------
#
# SINGAPORE
# Getting data for page no. :  321
#
# Data for pageno  321  successfully imported.
#  --------------------------------------------------------------------------------
#
# SLOVAK REPUBLIC
# Getting data for page no. :  323
#
# Data for pageno  323  successfully imported.
#  --------------------------------------------------------------------------------
#
# SLOVENIA
# Getting data for page no. :  325
#
# Data for pageno  325  successfully imported.
#  --------------------------------------------------------------------------------
#
# SOUTH AFRICA
# Getting data for page no. :  327
#
# Data for pageno  327  successfully imported.
#  --------------------------------------------------------------------------------
#
# SPAIN
# Getting data for page no. :  329
#
# Data for pageno  329  successfully imported.
#  --------------------------------------------------------------------------------
#
# SRI LANKA
# Getting data for page no. :  331
#
# Data for pageno  331  successfully imported.
#  --------------------------------------------------------------------------------
#
# SUDAN
# Getting data for page no. :  333
#
# Data for pageno  333  successfully imported.
#  --------------------------------------------------------------------------------
#
# SURINAME
# Getting data for page no. :  335
#
# Data for pageno  335  successfully imported.
#  --------------------------------------------------------------------------------
#
# SWEDEN
# Getting data for page no. :  337
#
# Data for pageno  337  successfully imported.
#  --------------------------------------------------------------------------------
#
# SWITZERLAND
# Getting data for page no. :  339
#
# Data for pageno  339  successfully imported.
#  --------------------------------------------------------------------------------
#
# SYRIAN ARAB REPUBLIC
# Getting data for page no. :  341
#
# Data for pageno  341  successfully imported.
#  --------------------------------------------------------------------------------
#
# TAIWAN
# Getting data for page no. :  343
#
# Data for pageno  343  successfully imported.
#  --------------------------------------------------------------------------------
#
# TAJIKISTAN
# Getting data for page no. :  345
# Data for pageno  345  successfully imported.
#  --------------------------------------------------------------------------------
#
# TANZANIA
# Getting data for page no. :  347
#
# Data for pageno  347  successfully imported.
#  --------------------------------------------------------------------------------
#
# THAILAND
# Getting data for page no. :  349
#
# Data for pageno  349  successfully imported.
#  --------------------------------------------------------------------------------
#
# TIMOR-LESTE
# Getting data for page no. :  351
#
# Data for pageno  351  successfully imported.
#  --------------------------------------------------------------------------------
#
# TOGO
# Getting data for page no. :  353
#
# Data for pageno  353  successfully imported.
#  --------------------------------------------------------------------------------
#
# TRINIDAD AND TOBAGO
# Getting data for page no. :  355
#
# Data for pageno  355  successfully imported.
#  --------------------------------------------------------------------------------
#
# TUNISIA
# Getting data for page no. :  357
#
# Data for pageno  357  successfully imported.
#  --------------------------------------------------------------------------------
#
# TURKEY
# Getting data for page no. :  359
#
# Data for pageno  359  successfully imported.
#  --------------------------------------------------------------------------------
#
# UGANDA
# Getting data for page no. :  361
#
# Data for pageno  361  successfully imported.
#  --------------------------------------------------------------------------------
#
# UKRAINE
# Getting data for page no. :  363
#
# Data for pageno  363  successfully imported.
#  --------------------------------------------------------------------------------
#
# UNITED ARAB EMIRATES
# Getting data for page no. :  364
#
# Data for pageno  364  successfully imported.
#  --------------------------------------------------------------------------------
#
# UNITED KINGDOM
# Getting data for page no. :  366
#
# Data for pageno  366  successfully imported.
#  --------------------------------------------------------------------------------
#
# UNITED STATES
# Getting data for page no. :  368
#
# Data for pageno  368  successfully imported.
#  --------------------------------------------------------------------------------
#
# URUGUAY
# Getting data for page no. :  370
#
# Data for pageno  370  successfully imported.
#  --------------------------------------------------------------------------------
#
# VENEZUELA, RB
# Getting data for page no. :  372
#
# Data for pageno  372  successfully imported.
#  --------------------------------------------------------------------------------
#
# VIETNAM
# Getting data for page no. :  374
#
# Data for pageno  374  successfully imported.
#  --------------------------------------------------------------------------------
#
# YEMEN, REP. OF
# Getting data for page no. :  376
#
# Data for pageno  376  successfully imported.
#  --------------------------------------------------------------------------------
#
# ZAMBIA
# Getting data for page no. :  378
#
# Data for pageno  378  successfully imported.
#  --------------------------------------------------------------------------------
#
# ZIMBABWE

# %%
store_data(clean_transpose(datadict))
# Out:
# ----------------------------------------Done----------------------------------------
